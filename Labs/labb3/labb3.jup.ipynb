# %% [markdown]
# ### $f(x) = −0.489x$

# %%
from labb3 import readfile,categories,write_file,plott

k = -0.489
m = 0

data = readfile()
label_data = categories(data, k, m)
write_file(label_data)
# print(f"f(x)= {k}x")
plott(label_data, k, m)

# %% [markdown]
# ### $g(x) = −2x + 0.16$

# %%
from labb3 import readfile,categories,write_file,plott

k = -2
m = 0.16

data = readfile()
label_data = categories(data, k, m)
write_file(label_data)
# print(f"g(x)= {k}x + {m}")
plott(label_data, k, m)

# %% [markdown]
# ### $h(x) = −1.08x − 0.1$

# %%
from labb3 import readfile,categories,write_file,plott

k = -1.08
m = -0.1

data = readfile()
label_data = categories(data, k, m)
write_file(label_data)
# print(f"h(x)= {k}x {m}")
plott(label_data, k, m)

# %% [markdown]
# # Rapport
#  Då skillnaden på klassifieringen existerar är den dock markant, och ser inte att någon linje är att föredra mer än någon annan.
