# %% [markdown]
# # Laboration - Dataprocessing

# %% [markdown]
# ### (a)
# Läs in csv fil

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

college = pd.read_csv("College.csv")

# %% [markdown]
# ### (b)
# Clean data

# %%
college2 = pd.read_csv("College.csv", index_col=0)
college3 = college.rename({"Unnamed: 0": "College"}, axis=1)
college3 = college3.set_index("College")
college = college3
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# ### (c)
# Describe method

# %%
""" C) Use the describe """
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### (d)
# Scattermatrix

# %%
""" D) Plot scatter matrix """
columns = ["Top10perc", "Apps", "Enroll"]
pd.plotting.scatter_matrix(college[columns], figsize=(10,10))
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# ### (e)
# Boxplot Outstate vs Private

# %%
""" E) Boxplot"""
fig, axs = plt.subplots(1,1)
sns.boxplot(data=college,x="Private",y='Outstate',ax=axs)
# Out:
# <Axes: xlabel='Private', ylabel='Outstate'>

# %% [markdown]
# ### (f)
# Boxplot Elite vs Outstate \
# Elite - Skolor som har över 50% av elever som är top10pers \
# Outstate - Avgiften för skolan.

# %%
college["Elite"] = pd.cut(college["Top10perc"], [0,50,100], labels=["No","Yes"])
print(college.value_counts("Elite"))
fig, axs = plt.subplots(1,1)
sns.boxplot(data=college, x="Elite", y='Outstate', ax=axs)
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64
# <Axes: xlabel='Elite', ylabel='Outstate'>

# %% [markdown]
# ### (g)
# 2x2 subplots

# %%
fig, ((enroll, grad_rate), (sf_ratio, phd)) = plt.subplots(2,2, figsize=(10,8))

enroll.hist(data=college, x="Enroll", label="Enroll", bins=10)
enroll.set_title("Enroll")
grad_rate.hist(data=college, x="Grad.Rate", label="Grad.Rate", bins=15)
grad_rate.set_title("Grad.Rate")
sf_ratio.hist(data=college, x="S.F.Ratio", bins=30)
sf_ratio.set_title("SF Ratio")
phd.hist(data=college, x="PhD",bins=20)
phd.set_title("Teachers with PhD")

# TODO Fixa binning så de flyter
# Out:
# Text(0.5, 1.0, 'Teachers with PhD')

# %% [markdown]
# ### (h)
# Summering, personliga upptäckter

# %% [markdown]
# Topp 15 grad rated college skolor och dess utgift per elev.

# %%
college["Grad.Rate"].describe()
college[college["Grad.Rate"] == 118] # Hittade ett fel i grad.rate.

highest_g_rate = college.sort_values("Grad.Rate")

highest_g_rate = highest_g_rate.head(776)
highest_g_rate = highest_g_rate.tail(15).reset_index()

fig, ax1 = plt.subplots()
ax1.barh(highest_g_rate["College"], highest_g_rate["Grad.Rate"], height=0.5, label="Grad.Rate", color="blue", alpha=0.5)
ax1.set_xlabel('Graduation Rate %')
ax1.set_xlim(0, 100)


ax2 = ax1.twiny()
ax2.barh(highest_g_rate["College"], highest_g_rate["Expend"], height=0.5, label="Expend", color="green")
ax2.set_xlabel('Expenditures $/student')
plt.title("College expends per student and graduation rate")
fig.legend(title="Graduation rate vs Expend", bbox_to_anchor=(0.9, 0.9), loc='upper left')


plt.show()

# %% [markdown]
# En överblick på de 15 skolorna som har högst procentuell eximinationer och dess utgift per elev. Mest troligt har skolorna olika program och därför varierar utgifterna mycket.\
# Det känns tryggt att de generella topskolorna som Harvard, Yale och Colombia har de högsta utgifterna men också imponerande att de har bland de högsta examensfrekvens.

# %%
elite = college.sort_values("Top10perc").tail()

top_elite_budget = elite[["Outstate","Expend","Personal"]]

top_elite_budget.plot(kind="barh", figsize=(15,4))
plt.title("Elite colleges cashflow")
plt.xlabel("$")
plt.tight_layout()

# %% [markdown]
# - Outstate : Out-of-state tuition
# - Expend : Instructional expenditure per student
# - Personal : Estimated personal spending
#
# Framtaget topp 5 elitskolor och dess kringkostnader.
# Jag fösökte undersöka pengarflödet kopplat till skolorna, det blir ganska platt när jag inte kan indentifiera vilka kostnader eleven gör kontra skolorna.

# %%
top_elite = elite[["Apps", "Accept", "Enroll"]]

top_elite.plot(kind="bar", figsize=(15,8))
plt.title("Elites Apps vs Accept vs Enroll")
plt.ylabel("Students")
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Samma skolor och dess antal ansökningar, beviljade ansökningar och elever som börjat skolan.

# %%
college["Rate"] = college["Accept"]/college["Apps"]
rate = college.sort_values("Rate", ascending=False).reset_index().head(10)

# ax = rate["College"].plot(kind='bar', figsize=(10, 6))
ax =plt.barh(rate["College"], rate["Rate"])
plt.title("Schools whose acceptance rate is highest")

plt.xlabel("Acceptance Rate (%)")

plt.show()

# %% [markdown]
# De 10 skolor som har högst acceptansgrad, varav 7 av dem har 100% acceptanssgrad.
