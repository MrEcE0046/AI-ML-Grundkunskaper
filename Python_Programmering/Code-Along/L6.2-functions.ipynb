# %% [markdown]
# # Big ideas in programming
#
# - Logical thinkin
# - Formal language and syntax
# - Program består av variabler och konstanter
# - Parameters
# - Flow control
# - Function, process, method
# - Algorithm
# - Data structures
# -  Composition / Decomposition
# - Reuseability / klippa och klistra kod - Dont repeat yourself, (anropa en function)
# -
# -

# %% [markdown]
# ## Andragradsfunktioner
#
# $ax^2+bx+c=0$

# %%
import numpy as np
q_term = [1, 2, 1]

def quadratic_solver(coeff):
    a, b, c = coeff
    x1 = np.divide(-b + np.sqrt(np.square(b) - 4*a*c), 2*a)
    x0 = np.divide(-b - np.sqrt(np.square(b) - 4*a*c), 2*a)
    return x0, x1

print(quadratic_solver(q_term))
# Out:
# (np.float64(-1.0), np.float64(-1.0))

# %%
# Year 0 = 1960
for year in range(70):
    pasta_consumption = .791 * np.exp(.0526*year)
    if pasta_consumption > 15:
        print(f"Year {year+1960} is the first year that pasta consumption reaches 15kg")
        break
# Out:
# Year 2016 is the first year that pasta consumption reaches 15kg

# %%
import matplotlib.pyplot as plt
pasta_per_year = []
for year in range(140):
    pasta_consumption = .791 * np.exp(.0526*year)
    pasta_per_year.append(pasta_consumption)
    #pasta_per_year += [pasta_consumption] Kan man också skriva
plt.plot(range(1960, 2100), pasta_per_year)
plt.xlabel("Y e a r")
plt.ylabel("Pasta consumption in kg")
plt.title("Pasta consumption in kg per person from year 1960")
# Out:
# Text(0.5, 1.0, 'Pasta consumption in kg per person from year 1960')

# %%
import matplotlib.pyplot as plt


x = list(range(-10, 10))
k = 1
m = 2
y = [k*x*m for x in x]

plt.plot(x,y)
plt.title("plot y = 2x + 2")
plt.ylabel("x")
plt.ylabel("y")
plt.ylim((0, 10))
plt.xlim((0, 10))
# Out:
# (0.0, 10.0)
