# %% [markdown]
# <a href="https://colab.research.google.com/github/kokchun/Machine-learning-AI22/blob/main/Exercises/E03_overfit_regularization.ipynb" target="_parent"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> &nbsp; to see hints and answers.

# %% [markdown]
# ---
# # Overfit and regularization exercises
#
# ---
# These are introductory exercises in Machine learning with focus in **overfitting and regularization** .
#
# <p class = "alert alert-info" role="alert"><b>Note</b> that sometimes you don't get exactly the same answer as I get, but it doesn't neccessarily mean it is wrong. Could be some parameters, randomization, that we have different. Also very important is that in the future there won't be any answer sheets, use your skills in data analysis, mathematics and statistics to back up your work.</p>
#
# <p class = "alert alert-info" role="alert"><b>Note</b> that in cases when you start to repeat code, try not to. Create functions to reuse code instead. </p>
#
# <p class = "alert alert-info" role="alert"><b>Remember</b> to use <b>descriptive variable, function, index </b> and <b> column names</b> in order to get readable code </p>
#
# The number of stars (\*), (\*\*), (\*\*\*) denotes the difficulty level of the task
#
# ---

# %% [markdown]
# ## 0. Tips data EDA (*)
#
# In the whole exercise, we will work with the "tips" dataset from seaborn dataset. Start by loading dataset "tips" from the ```load_dataset``` method in seaborn module. The goal will be to use polynomial linear regression to predict tips.
#
# &nbsp; a) Start by doing some initial EDA such as info(), describe().
#
# &nbsp; b) Use describe only on those columns that are relevant to get statistical information from. Plot the descriptive statistics for each numerical column, with a adequate plot type (e.g. barplot).
#
# &nbsp; c) Based on the initial EDA, make some more plots on things you think could be worthwhile to investigate.
#
# &nbsp; d) Try discuss your findings with yourself/colleague and draw some conclusions if possible. Note that in reality, it is important to be able to communicate your findings so that other people in your team/customers/stakeholders etc. get an understanding of the data and realizes the importance of your role as a data scientist/analyst.
#
# <details>
#
# <summary>Answer</summary>
#
#
# b)
# <img src="../assets/df_describe.png" height="300"/>
#
# c) Here are some example plots
#
# <img src="../assets/tips_EDA.png" height="300"/>
#
# <img src="../assets/tips_smoke_sex.png" width="500"/>
#
# <img src="../assets/tips_bar_sex.png" width="300"/>
#
#
# d) For example:
# - there are almost double amount of females represented in the dataset
# - there are very few tables with 1 person eating, and they usually give very low tip
# - female and male tip somewhat similar
#
# </details>
#
# ---

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
df.dropna()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df['tip'], df['total_bill'], c=df['sex'].map({'Male': 'blue', 'Female': 'red'}))
plt.xlabel('Tip')
plt.ylabel('Total Bill')
plt.title('Scatterplot av Total Bill vs Tip')
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', label='Male', markerfacecolor='blue', markersize=7),
                     plt.Line2D([0], [0], marker='o', color='w', label='Female', markerfacecolor='red', markersize=7)],
           loc='upper left')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Skapa scatterplot med etiketter för varje kön
plt.scatter(df[df['sex'] == 'Male']['tip'], df[df['sex'] == 'Male']['total_bill'], c='blue', label='Male')  # Scatter för Male
plt.scatter(df[df['sex'] == 'Female']['tip'], df[df['sex'] == 'Female']['total_bill'], c='red', label='Female')  # Scatter för Female

# Etiketter och titel
plt.xlabel('Tip')
plt.ylabel('Total Bill')
plt.title('Scatterplot av Total Bill vs Tip')

# Automatisk legend baserat på de etiketter vi lade till
plt.legend(loc='upper left')

# Aktivera grid
plt.grid(True)

# Visa grafen
plt.show()

# %%
sns.scatterplot(x="tip", y="total_bill", data=df, hue="day")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip", y="total_bill", data=df, hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(df["tip"], kde=True, bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.barplot(x="sex",y="tip", data=df, legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day", y="tip", data=df, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y="tip", data=df, hue="sex", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="tip", y="total_bill", data=df, kind="reg")

# %%
sns.pairplot(df.select_dtypes(["number"]), hue="tip")

# %%
df_drop = df.drop(columns=["sex", "smoker", "day", "time"])
sns.heatmap(df_drop.corr(), annot=True)
# Mindre är bättre
# Out:
# <Axes: >

# %%
plt.boxplot([df[df["time"] == time]["total_bill"] for time in df["time"].unique()])
plt.xlabel("time")
plt.ylabel("Total Bill")
plt.title("Boxplot av Total Bill för varje Day")
plt.show()

# %%
df = df.iloc[:20]
df.style.format(precision=1).background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_ec4ad_row0_col0, #T_ec4ad_row18_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ec4ad_row0_col1, #T_ec4ad_row0_col6, #T_ec4ad_row3_col6, #T_ec4ad_row6_col0, #T_ec4ad_row6_col6, #T_ec4ad_row8_col6, #T_ec4ad_row9_col6, #T_ec4ad_row10_col6, #T_ec4ad_row12_col6, #T_ec4ad_row14_col6, #T_ec4ad_row15_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ec4ad_row1_col0, #T_ec4ad_row16_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ec4ad_row1_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ec4ad_row1_col6, #T_ec4ad_row2_col6, #T_ec4ad_row14_col1, #T_ec4ad_row16_col6, #T_ec4ad_row17_col6, #T_ec4ad_row18_col6, #T_ec4ad_row19_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ec4ad_row2_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ec4ad_row2_col1, #T_ec4ad_row5_col0, #T_ec4ad_row18_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_ec4ad_row3_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ec4ad_row3_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_ec4ad_row4_col0 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_ec4ad_row4_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_ec4ad_row4_col6, #T_ec4ad_row5_col6, #T_ec4ad_row7_col6, #T_ec4ad_row11_col0, #T_ec4ad_row11_col1, #T_ec4ad_row11_col6, #T_ec4ad_row13_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ec4ad_row5_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_ec4ad_row6_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ec4ad_row7_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_ec4ad_row7_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_ec4ad_row8_col0, #T_ec4ad_row8_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ec4ad_row9_col0, #T_ec4ad_row14_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ec4ad_row9_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_ec4ad_row10_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ec4ad_row10_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ec4ad_row12_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ec4ad_row12_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_ec4ad_row13_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ec4ad_row13_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ec4ad_row15_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_ec4ad_row15_col1 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_ec4ad_row16_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ec4ad_row17_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ec4ad_row17_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_ec4ad_row19_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ec4ad_row19_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# </style>
# <table id="T_ec4ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec4ad_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_ec4ad_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_ec4ad_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_ec4ad_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_ec4ad_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_ec4ad_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_ec4ad_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec4ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec4ad_row0_col0" class="data row0 col0" >17.0</td>
#       <td id="T_ec4ad_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_ec4ad_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_ec4ad_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_ec4ad_row0_col4" class="data row0 col4" >Sun</td>
#       <td id="T_ec4ad_row0_col5" class="data row0 col5" >Dinner</td>
#       <td id="T_ec4ad_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec4ad_row1_col0" class="data row1 col0" >10.3</td>
#       <td id="T_ec4ad_row1_col1" class="data row1 col1" >1.7</td>
#       <td id="T_ec4ad_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_ec4ad_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_ec4ad_row1_col4" class="data row1 col4" >Sun</td>
#       <td id="T_ec4ad_row1_col5" class="data row1 col5" >Dinner</td>
#       <td id="T_ec4ad_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec4ad_row2_col0" class="data row2 col0" >21.0</td>
#       <td id="T_ec4ad_row2_col1" class="data row2 col1" >3.5</td>
#       <td id="T_ec4ad_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_ec4ad_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_ec4ad_row2_col4" class="data row2 col4" >Sun</td>
#       <td id="T_ec4ad_row2_col5" class="data row2 col5" >Dinner</td>
#       <td id="T_ec4ad_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec4ad_row3_col0" class="data row3 col0" >23.7</td>
#       <td id="T_ec4ad_row3_col1" class="data row3 col1" >3.3</td>
#       <td id="T_ec4ad_row3_col2" class="data row3 col2" >Male</td>
#       <td id="T_ec4ad_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_ec4ad_row3_col4" class="data row3 col4" >Sun</td>
#       <td id="T_ec4ad_row3_col5" class="data row3 col5" >Dinner</td>
#       <td id="T_ec4ad_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec4ad_row4_col0" class="data row4 col0" >24.6</td>
#       <td id="T_ec4ad_row4_col1" class="data row4 col1" >3.6</td>
#       <td id="T_ec4ad_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_ec4ad_row4_col3" class="data row4 col3" >No</td>
#       <td id="T_ec4ad_row4_col4" class="data row4 col4" >Sun</td>
#       <td id="T_ec4ad_row4_col5" class="data row4 col5" >Dinner</td>
#       <td id="T_ec4ad_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ec4ad_row5_col0" class="data row5 col0" >25.3</td>
#       <td id="T_ec4ad_row5_col1" class="data row5 col1" >4.7</td>
#       <td id="T_ec4ad_row5_col2" class="data row5 col2" >Male</td>
#       <td id="T_ec4ad_row5_col3" class="data row5 col3" >No</td>
#       <td id="T_ec4ad_row5_col4" class="data row5 col4" >Sun</td>
#       <td id="T_ec4ad_row5_col5" class="data row5 col5" >Dinner</td>
#       <td id="T_ec4ad_row5_col6" class="data row5 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ec4ad_row6_col0" class="data row6 col0" >8.8</td>
#       <td id="T_ec4ad_row6_col1" class="data row6 col1" >2.0</td>
#       <td id="T_ec4ad_row6_col2" class="data row6 col2" >Male</td>
#       <td id="T_ec4ad_row6_col3" class="data row6 col3" >No</td>
#       <td id="T_ec4ad_row6_col4" class="data row6 col4" >Sun</td>
#       <td id="T_ec4ad_row6_col5" class="data row6 col5" >Dinner</td>
#       <td id="T_ec4ad_row6_col6" class="data row6 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ec4ad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ec4ad_row7_col0" class="data row7 col0" >26.9</td>
#       <td id="T_ec4ad_row7_col1" class="data row7 col1" >3.1</td>
#       <td id="T_ec4ad_row7_col2" class="data row7 col2" >Male</td>
#       <td id="T_ec4ad_row7_col3" class="data row7 col3" >No</td>
#       <td id="T_ec4ad_row7_col4" class="data row7 col4" >Sun</td>
#       <td id="T_ec4ad_row7_col5" class="data row7 col5" >Dinner</td>
#       <td id="T_ec4ad_row7_col6" class="data row7 col6" >4</td>
#     </tr>

# %%
df.style.format(precision=1).bar(subset="total_bill", color="green")
# Out:
# <style type="text/css">
# #T_b51ab_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 48.2%, transparent 48.2%);
# }
# #T_b51ab_row1_col0, #T_b51ab_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 29.3%, transparent 29.3%);
# }
# #T_b51ab_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 59.6%, transparent 59.6%);
# }
# #T_b51ab_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 67.2%, transparent 67.2%);
# }
# #T_b51ab_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 69.7%, transparent 69.7%);
# }
# #T_b51ab_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 71.7%, transparent 71.7%);
# }
# #T_b51ab_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 24.9%, transparent 24.9%);
# }
# #T_b51ab_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 76.2%, transparent 76.2%);
# }
# #T_b51ab_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 42.7%, transparent 42.7%);
# }
# #T_b51ab_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 41.9%, transparent 41.9%);
# }
# #T_b51ab_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 29.1%, transparent 29.1%);
# }
# #T_b51ab_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_b51ab_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 43.7%, transparent 43.7%);
# }
# #T_b51ab_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 52.3%, transparent 52.3%);
# }
# #T_b51ab_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 42.1%, transparent 42.1%);
# }
# #T_b51ab_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 61.2%, transparent 61.2%);
# }
# #T_b51ab_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 46.2%, transparent 46.2%);
# }
# #T_b51ab_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 48.1%, transparent 48.1%);
# }
# #T_b51ab_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 58.6%, transparent 58.6%);
# }
# </style>
# <table id="T_b51ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b51ab_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_b51ab_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_b51ab_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_b51ab_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_b51ab_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_b51ab_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_b51ab_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b51ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b51ab_row0_col0" class="data row0 col0" >17.0</td>
#       <td id="T_b51ab_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_b51ab_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_b51ab_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_b51ab_row0_col4" class="data row0 col4" >Sun</td>
#       <td id="T_b51ab_row0_col5" class="data row0 col5" >Dinner</td>
#       <td id="T_b51ab_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b51ab_row1_col0" class="data row1 col0" >10.3</td>
#       <td id="T_b51ab_row1_col1" class="data row1 col1" >1.7</td>
#       <td id="T_b51ab_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_b51ab_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_b51ab_row1_col4" class="data row1 col4" >Sun</td>
#       <td id="T_b51ab_row1_col5" class="data row1 col5" >Dinner</td>
#       <td id="T_b51ab_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b51ab_row2_col0" class="data row2 col0" >21.0</td>
#       <td id="T_b51ab_row2_col1" class="data row2 col1" >3.5</td>
#       <td id="T_b51ab_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_b51ab_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_b51ab_row2_col4" class="data row2 col4" >Sun</td>
#       <td id="T_b51ab_row2_col5" class="data row2 col5" >Dinner</td>
#       <td id="T_b51ab_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b51ab_row3_col0" class="data row3 col0" >23.7</td>
#       <td id="T_b51ab_row3_col1" class="data row3 col1" >3.3</td>
#       <td id="T_b51ab_row3_col2" class="data row3 col2" >Male</td>
#       <td id="T_b51ab_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_b51ab_row3_col4" class="data row3 col4" >Sun</td>
#       <td id="T_b51ab_row3_col5" class="data row3 col5" >Dinner</td>
#       <td id="T_b51ab_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b51ab_row4_col0" class="data row4 col0" >24.6</td>
#       <td id="T_b51ab_row4_col1" class="data row4 col1" >3.6</td>
#       <td id="T_b51ab_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_b51ab_row4_col3" class="data row4 col3" >No</td>
#       <td id="T_b51ab_row4_col4" class="data row4 col4" >Sun</td>
#       <td id="T_b51ab_row4_col5" class="data row4 col5" >Dinner</td>
#       <td id="T_b51ab_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b51ab_row5_col0" class="data row5 col0" >25.3</td>
#       <td id="T_b51ab_row5_col1" class="data row5 col1" >4.7</td>
#       <td id="T_b51ab_row5_col2" class="data row5 col2" >Male</td>
#       <td id="T_b51ab_row5_col3" class="data row5 col3" >No</td>
#       <td id="T_b51ab_row5_col4" class="data row5 col4" >Sun</td>
#       <td id="T_b51ab_row5_col5" class="data row5 col5" >Dinner</td>
#       <td id="T_b51ab_row5_col6" class="data row5 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b51ab_row6_col0" class="data row6 col0" >8.8</td>
#       <td id="T_b51ab_row6_col1" class="data row6 col1" >2.0</td>
#       <td id="T_b51ab_row6_col2" class="data row6 col2" >Male</td>
#       <td id="T_b51ab_row6_col3" class="data row6 col3" >No</td>
#       <td id="T_b51ab_row6_col4" class="data row6 col4" >Sun</td>
#       <td id="T_b51ab_row6_col5" class="data row6 col5" >Dinner</td>
#       <td id="T_b51ab_row6_col6" class="data row6 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b51ab_row7_col0" class="data row7 col0" >26.9</td>
#       <td id="T_b51ab_row7_col1" class="data row7 col1" >3.1</td>
#       <td id="T_b51ab_row7_col2" class="data row7 col2" >Male</td>
#       <td id="T_b51ab_row7_col3" class="data row7 col3" >No</td>
#       <td id="T_b51ab_row7_col4" class="data row7 col4" >Sun</td>
#       <td id="T_b51ab_row7_col5" class="data row7 col5" >Dinner</td>
#       <td id="T_b51ab_row7_col6" class="data row7 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b51ab_row8_col0" class="data row8 col0" >15.0</td>
#       <td id="T_b51ab_row8_col1" class="data row8 col1" >2.0</td>
#       <td id="T_b51ab_row8_col2" class="data row8 col2" >Male</td>
#       <td id="T_b51ab_row8_col3" class="data row8 col3" >No</td>
#       <td id="T_b51ab_row8_col4" class="data row8 col4" >Sun</td>
#       <td id="T_b51ab_row8_col5" class="data row8 col5" >Dinner</td>
#       <td id="T_b51ab_row8_col6" class="data row8 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b51ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b51ab_row9_col0" class="data row9 col0" >14.8</td>
#       <td id="T_b51ab_row9_col1" class="d

# %%
df.style.format(precision=1).highlight_between(subset="total_bill", left=5, right=12)
# Out:
# <style type="text/css">
# #T_05145_row1_col0, #T_05145_row6_col0, #T_05145_row10_col0, #T_05145_row16_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_05145">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05145_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_05145_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_05145_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_05145_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_05145_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_05145_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_05145_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05145_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05145_row0_col0" class="data row0 col0" >17.0</td>
#       <td id="T_05145_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_05145_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_05145_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_05145_row0_col4" class="data row0 col4" >Sun</td>
#       <td id="T_05145_row0_col5" class="data row0 col5" >Dinner</td>
#       <td id="T_05145_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05145_row1_col0" class="data row1 col0" >10.3</td>
#       <td id="T_05145_row1_col1" class="data row1 col1" >1.7</td>
#       <td id="T_05145_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_05145_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_05145_row1_col4" class="data row1 col4" >Sun</td>
#       <td id="T_05145_row1_col5" class="data row1 col5" >Dinner</td>
#       <td id="T_05145_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05145_row2_col0" class="data row2 col0" >21.0</td>
#       <td id="T_05145_row2_col1" class="data row2 col1" >3.5</td>
#       <td id="T_05145_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_05145_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_05145_row2_col4" class="data row2 col4" >Sun</td>
#       <td id="T_05145_row2_col5" class="data row2 col5" >Dinner</td>
#       <td id="T_05145_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05145_row3_col0" class="data row3 col0" >23.7</td>
#       <td id="T_05145_row3_col1" class="data row3 col1" >3.3</td>
#       <td id="T_05145_row3_col2" class="data row3 col2" >Male</td>
#       <td id="T_05145_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_05145_row3_col4" class="data row3 col4" >Sun</td>
#       <td id="T_05145_row3_col5" class="data row3 col5" >Dinner</td>
#       <td id="T_05145_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05145_row4_col0" class="data row4 col0" >24.6</td>
#       <td id="T_05145_row4_col1" class="data row4 col1" >3.6</td>
#       <td id="T_05145_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_05145_row4_col3" class="data row4 col3" >No</td>
#       <td id="T_05145_row4_col4" class="data row4 col4" >Sun</td>
#       <td id="T_05145_row4_col5" class="data row4 col5" >Dinner</td>
#       <td id="T_05145_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_05145_row5_col0" class="data row5 col0" >25.3</td>
#       <td id="T_05145_row5_col1" class="data row5 col1" >4.7</td>
#       <td id="T_05145_row5_col2" class="data row5 col2" >Male</td>
#       <td id="T_05145_row5_col3" class="data row5 col3" >No</td>
#       <td id="T_05145_row5_col4" class="data row5 col4" >Sun</td>
#       <td id="T_05145_row5_col5" class="data row5 col5" >Dinner</td>
#       <td id="T_05145_row5_col6" class="data row5 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_05145_row6_col0" class="data row6 col0" >8.8</td>
#       <td id="T_05145_row6_col1" class="data row6 col1" >2.0</td>
#       <td id="T_05145_row6_col2" class="data row6 col2" >Male</td>
#       <td id="T_05145_row6_col3" class="data row6 col3" >No</td>
#       <td id="T_05145_row6_col4" class="data row6 col4" >Sun</td>
#       <td id="T_05145_row6_col5" class="data row6 col5" >Dinner</td>
#       <td id="T_05145_row6_col6" class="data row6 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_05145_row7_col0" class="data row7 col0" >26.9</td>
#       <td id="T_05145_row7_col1" class="data row7 col1" >3.1</td>
#       <td id="T_05145_row7_col2" class="data row7 col2" >Male</td>
#       <td id="T_05145_row7_col3" class="data row7 col3" >No</td>
#       <td id="T_05145_row7_col4" class="data row7 col4" >Sun</td>
#       <td id="T_05145_row7_col5" class="data row7 col5" >Dinner</td>
#       <td id="T_05145_row7_col6" class="data row7 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_05145_row8_col0" class="data row8 col0" >15.0</td>
#       <td id="T_05145_row8_col1" class="data row8 col1" >2.0</td>
#       <td id="T_05145_row8_col2" class="data row8 col2" >Male</td>
#       <td id="T_05145_row8_col3" class="data row8 col3" >No</td>
#       <td id="T_05145_row8_col4" class="data row8 col4" >Sun</td>
#       <td id="T_05145_row8_col5" class="data row8 col5" >Dinner</td>
#       <td id="T_05145_row8_col6" class="data row8 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_05145_row9_col0" class="data row9 col0" >14.8</td>
#       <td id="T_05145_row9_col1" class="data row9 col1" >3.2</td>
#       <td id="T_05145_row9_col2" class="data row9 col2" >Male</td>
#       <td id="T_05145_row9_col3" class="data row9 col3" >No</td>
#       <td id="T_05145_row9_col4" class="data row9 col4" >Sun</td>
#       <td id="T_05145_row9_col5" class="data row9 col5" >Dinner</td>
#       <td id="T_05145_row9_col6" class="data row9 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_05145_row10_col0" class="data row10 col0" >10.3</td>
#       <td id="T_05145_row10_col1" class="data row10 col1" >1.7</td>
#       <td id="T_05145_row10_col2" class="data row10 col2" >Male</td>
#       <td id="T_05145_row10_col3" class="data row10 col3" >No</td>
#       <td id="T_05145_row10_col4" class="data row10 col4" >Sun</td>
#       <td id="T_05145_row10_col5" class="data row10 col5" >Dinner</td>
#       <td id="T_05145_row10_col6" class="data row10 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_05145_row11_col0" class="data row11 col0" >35.3</td>
#       <td id="T_05145_row11_col1" class="data row11 col1" >5.0</td>
#       <td id="T_05145_row11_col2" class="data row11 col2" >Female</td>
#       <td id="T_05145_row11_col3" class="data row11 col3" >No</td>
#       <td id="T_05145_row11_col4" class="data row11 col4" >Sun</td>
#       <td id="T_05145_row11_col5" class="data row11 col5" >Dinner</td>
#       <td id="T_05145_row11_col6" class="data row11 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05145_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_05145_row12_col0" class="data row12 col0" >15.4</td>
#       <td id="T_05145_row12_col1" class="data row12 col1" >1.6</td>
#       <td id="T_05145_row12_col2" class="data row12 col2" >Male</td>
#       <td id="T_05145_row12_col3" class="data row12 col3" >No</td>
#       <td id="T_05145_row12_col4" class="data row12 col4" >Sun</td>
#       <td id="T_05145_row

# %%
def super_style(style):
    style.format(precision=1).bar(vmin=0, color="pink", subset=["tip"])
    style.format(precision=1).background_gradient(subset=["total_bill"])
    style.format(precision=1).highlight_between(left=2, right=3, subset=["size"])
    return style

df.style.pipe(super_style)
# Out:
# <style type="text/css">
# #T_35bbb_row0_col0, #T_35bbb_row18_col0, #T_35bbb_row37_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_35bbb_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 10.1%, transparent 10.1%);
# }
# #T_35bbb_row0_col6, #T_35bbb_row1_col6, #T_35bbb_row2_col6, #T_35bbb_row3_col6, #T_35bbb_row6_col6, #T_35bbb_row8_col6, #T_35bbb_row9_col6, #T_35bbb_row10_col6, #T_35bbb_row12_col6, #T_35bbb_row14_col6, #T_35bbb_row15_col6, #T_35bbb_row16_col6, #T_35bbb_row17_col6, #T_35bbb_row18_col6, #T_35bbb_row19_col6, #T_35bbb_row20_col6, #T_35bbb_row21_col6, #T_35bbb_row22_col6, #T_35bbb_row24_col6, #T_35bbb_row26_col6, #T_35bbb_row27_col6, #T_35bbb_row28_col6, #T_35bbb_row29_col6, #T_35bbb_row30_col6, #T_35bbb_row32_col6, #T_35bbb_row34_col6, #T_35bbb_row35_col6, #T_35bbb_row36_col6, #T_35bbb_row37_col6, #T_35bbb_row38_col6, #T_35bbb_row39_col6, #T_35bbb_row40_col6, #T_35bbb_row41_col6, #T_35bbb_row42_col6, #T_35bbb_row43_col6, #T_35bbb_row45_col6, #T_35bbb_row46_col6, #T_35bbb_row48_col6, #T_35bbb_row49_col6, #T_35bbb_row50_col6, #T_35bbb_row51_col6, #T_35bbb_row53_col6, #T_35bbb_row55_col6, #T_35bbb_row57_col6, #T_35bbb_row58_col6, #T_35bbb_row60_col6, #T_35bbb_row61_col6, #T_35bbb_row62_col6, #T_35bbb_row64_col6, #T_35bbb_row65_col6, #T_35bbb_row66_col6, #T_35bbb_row68_col6, #T_35bbb_row69_col6, #T_35bbb_row70_col6, #T_35bbb_row71_col6, #T_35bbb_row72_col6, #T_35bbb_row73_col6, #T_35bbb_row74_col6, #T_35bbb_row75_col6, #T_35bbb_row76_col6, #T_35bbb_row78_col6, #T_35bbb_row79_col6, #T_35bbb_row80_col6, #T_35bbb_row81_col6, #T_35bbb_row83_col6, #T_35bbb_row84_col6, #T_35bbb_row86_col6, #T_35bbb_row87_col6, #T_35bbb_row88_col6, #T_35bbb_row89_col6, #T_35bbb_row90_col6, #T_35bbb_row91_col6, #T_35bbb_row92_col6, #T_35bbb_row93_col6, #T_35bbb_row94_col6, #T_35bbb_row96_col6, #T_35bbb_row97_col6, #T_35bbb_row98_col6, #T_35bbb_row99_col6, #T_35bbb_row100_col6, #T_35bbb_row101_col6, #T_35bbb_row102_col6, #T_35bbb_row103_col6, #T_35bbb_row104_col6, #T_35bbb_row105_col6, #T_35bbb_row106_col6, #T_35bbb_row107_col6, #T_35bbb_row108_col6, #T_35bbb_row109_col6, #T_35bbb_row110_col6, #T_35bbb_row112_col6, #T_35bbb_row113_col6, #T_35bbb_row114_col6, #T_35bbb_row115_col6, #T_35bbb_row117_col6, #T_35bbb_row118_col6, #T_35bbb_row120_col6, #T_35bbb_row121_col6, #T_35bbb_row122_col6, #T_35bbb_row123_col6, #T_35bbb_row124_col6, #T_35bbb_row126_col6, #T_35bbb_row127_col6, #T_35bbb_row128_col6, #T_35bbb_row129_col6, #T_35bbb_row130_col6, #T_35bbb_row131_col6, #T_35bbb_row132_col6, #T_35bbb_row133_col6, #T_35bbb_row134_col6, #T_35bbb_row135_col6, #T_35bbb_row136_col6, #T_35bbb_row137_col6, #T_35bbb_row138_col6, #T_35bbb_row139_col6, #T_35bbb_row140_col6, #T_35bbb_row144_col6, #T_35bbb_row145_col6, #T_35bbb_row146_col6, #T_35bbb_row147_col6, #T_35bbb_row148_col6, #T_35bbb_row149_col6, #T_35bbb_row150_col6, #T_35bbb_row151_col6, #T_35bbb_row152_col6, #T_35bbb_row158_col6, #T_35bbb_row161_col6, #T_35bbb_row162_col6, #T_35bbb_row163_col6, #T_35bbb_row164_col6, #T_35bbb_row165_col6, #T_35bbb_row166_col6, #T_35bbb_row168_col6, #T_35bbb_row169_col6, #T_35bbb_row170_col6, #T_35bbb_row171_col6, #T_35bbb_row172_col6, #T_35bbb_row173_col6, #T_35bbb_row174_col6, #T_35bbb_row175_col6, #T_35bbb_row176_col6, #T_35bbb_row177_col6, #T_35bbb_row178_col6, #T_35bbb_row179_col6, #T_35bbb_row181_col6, #T_35bbb_row182_col6, #T_35bbb_row184_col6, #T_35bbb_row186_col6, #T_35bbb_row188_col6, #T_35bbb_row189_col6, #T_35bbb_row190_col6, #T_35bbb_row191_col6, #T_35bbb_row192_col6, #T_35bbb_row193_col6, #T_35bbb_row194_col6, #T_35bbb_row195_col6, #T_35bbb_row196_col6, #T_35bbb_row198_col6, #T_35bbb_row199_col6, #T_35bbb_row200_col6, #T_35bbb_row201_col6, #T_35bbb_row202_col6, #T_35bbb_row203_col6, #T_35bbb_row205_col6, #T_35bbb_row206_col6, #T_35bbb_row208_col6, #T_35bbb_row209_col6, #T_35bbb_row210_col6, #T_35bbb_row213_col6, #T_35bbb_row214_col6, #T_35bbb_row215_col6, #T_35bbb_row217_col6, #T_35bbb_row218_col6, #T_35bbb_row220_col6, #T_35bbb_row221_col6, #T_35bbb_row223_col6, #T_35bbb_row224_col6, #T_35bbb_row225_col6, #T_35bbb_row226_col6, #T_35bbb_row228_col6, #T_35bbb_row229_col6, #T_35bbb_row231_col6, #T_35bbb_row232_col6, #T_35bbb_row233_col6, #T_35bbb_row234_col6, #T_35bbb_row235_ ...
#   background-color: yellow;
# }
# #T_35bbb_row1_col0, #T_35bbb_row10_col0, #T_35bbb_row16_col0, #T_35bbb_row51_col0, #T_35bbb_row82_col0, #T_35bbb_row136_col0, #T_35bbb_row196_col0, #T_35bbb_row226_col0, #T_35bbb_row235_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_35bbb_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 16.6%, transparent 16.6%);
# }
# #T_35bbb_row2_col0, #T_35bbb_row98_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_35bbb_row2_col1, #T_35bbb_row18_col1, #T_35bbb_row91_col1, #T_35bbb_row115_col1, #T_35bbb_row140_col1, #T_35bbb_row160_col1, #T_35bbb_row182_col1, #T_35bbb_row186_col1, #T_35bbb_row188_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 35.0%, transparent 35.0%);
# }
# #T_35bbb_row3_col0 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_35bbb_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 33.1%, transparent 33.1%);
# }
# #T_35bbb_row4_col0, #T_35bbb_row153_col0, #T_35bbb_row165_col0 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_35bbb_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 36.1%, transparent 36.1%);
# }
# #T_35bbb_row5_col0, #T_35bbb_row73_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_35bbb_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 47.1%, transparent 47.1%);
# }
# #T_35bbb_row6_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_35bbb_row6_col1, #T_35bbb_row26_col1, #T_35bbb_row27_col1, #T_35bbb_row36_col1, #T_35bbb_row61_col1, #T_35bbb_row86_col1, #T_35bbb_row123_col1, #T_35bbb_row127_col1, #T_35bbb_row128_col1, #T_35bbb_row133_col1, #T_35bbb_row136_col1, #T_35bbb_row137_col1, #T_35bbb_row138_col1, #T_35bbb_row149_col1, #T_35bbb_row151_col1, #T_35bbb_row153_col1, #T_35bbb_row154_col1, #T_35bbb_row159_col1, #T_35bbb_row162_col1, #T_35bbb_row163_col1, #T_35bbb_row169_col1, #T_35bbb_row176_col1, #T_35bbb_row177_col1, #T_35bbb_row187_col1, #T_35bbb_row196_col1, #T_35bbb_row198_col1, #T_35bbb_row199_col1, #T_35bbb_row202_col1, #T_35bbb_row210_col1, #T_35bbb_row226_col1, #T_35bbb_row230_col1, #T_35bbb_row240_col1, #T_35bbb_row241_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 20.0%, transparent 20.0%);
# }
# #T_35bbb_row7_col0, #T_35bbb_row72_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_35bbb_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 31.2%, transparent 31.2%);
# }
# #T_35bbb_row8_col0, #T_35bbb_row32_col0, #T_35bbb_row69_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_35bbb_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 19.6%, transparent 19.6%);
# }
# #T_35bbb_row9_col0, #T_35bbb_row74_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_35bbb_row9_col1, #T_35bbb_row205_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 32.3%, transparent 32.3%);
# }
# #T_35bbb_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 17.1%, transparent 17.1%);
# }
# #T_35bbb_row11_col0 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_35bbb_row11_col1, #T_35bbb_row39_col1, #T_35bbb_row46_col1, #T_35bbb_row73_col1, #T_35bbb_row83_col1, #T_35bbb_row142_col1, #T_35bbb_row143_col1, #T_35bbb_row156_col1, #T_35bbb_row185_col1, #T_35bbb_row197_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 50.0%, transparent 50.0%);
# }
# #T_35bbb_row12_col0, #T_35bbb_row101_col0, #T_35bbb_row193_col0, #T_35bbb_row234_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_35bbb_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 15.7%, transparen

# %%
df = sns.load_dataset("tips")
pd.options.plotting.backend="plotly"
df.groupby("day")["total_bill"].mean().plot(kind="bar")
# Out:
# C:\Users\emil_\AppData\Local\Temp\ipykernel_17680\3725635402.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
pd.options.plotting.backend="plotly"
df.plot.scatter(x="total_bill",y="tip")

# %% [markdown]
# ## 1. Train|test split (*)
#
# Split the data into training part and testing part, using sklearn's train_test_split with test size of 0.3 and random_state 42.

# %%
from sklearn.model_selection import train_test_split

X, y = df.drop(columns=["sex", "smoker", "day", "time", "tip"]), df["tip"]
X

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((170, 2), (74, 2), (170,), (74,))

# %% [markdown]
# ---
# ## 2. Feature standardization (*)
#
# We need to normalize the data and in this case will be using feature standardization. Implement this yourself following this formula:
#
# $$X_{train}' = \frac{X_{train}-\mu_{train}}{\sigma_{train}}$$
#
# $$X_{test}' = \frac{X_{test}-\mu_{train}}{\sigma_{train}}$$
#
# , where $'$ denotes scaled, $\mu_{train}$ is the mean of the training data, $\sigma_{train}$ is the standard deviation of the training data. Note that it is very important that the mean and standard deviation is computed from the training data and not from testing data to avoid data leakage. Control the standard deviation and mean of $X_{train}'$ and $X_{test}'$. Is the results as you expect, why, why not?
#
# <details>
#
# <summary>Answer</summary>
#
# scaled_X_train (total_bill, size) mean: [ 6.79195262e-17 -1.98534000e-16]
#
# scaled_X_test (total_bill, size) mean: [-0.19137999 -0.04477934]
#
# scaled_X_train (total_bill, size) std: [1. 1.]
#
# scaled_X_test (total_bill, size) std: [0.92495673 1.06638889]
#
# </details>

# %%
import numpy as np

mean_X_train = X_train.mean()
std_X_train = X_train.std()
scaled_X_train = (X_train - mean_X_train) / std_X_train # normalisering av X_train

mean_X_test = X_test.mean()
std_X_test = X_test.std()
scaled_X_test = (X_test - mean_X_test) / std_X_test # normalisering av X_test

scaled_X_train["total_bill"].mean(), scaled_X_train["size"].mean()
# Out:
# (6.791952621236252e-17, -1.9853399969767506e-16)

# %%
from sklearn.preprocessing import StandardScaler
""" Standardisera train och test med scikit learn """

scaler = StandardScaler()
scale_X_train = scaler.fit_transform(X_train)
scale_X_test = scaler.transform(X_test)

print(scale_X_train[:,0].mean(), scale_X_train[:,1].mean())
print(np.mean(scale_X_train[:,0]), np.mean(scale_X_train[:,1])) # med numpy
# Out:
# 6.791952621236252e-17 -1.0449157878825003e-16
# 6.791952621236252e-17 -1.0449157878825003e-16

# %% [markdown]
# ---
# ## 3. Polynomial features (*)
#
# We want to investigate ```Polynomialfeatures``` from scikit-klearn in this task. Start by instantiating an object of type ```PolynomialFeatures``` with degree 2. Now do the following:
#
# - use the method fit on $X_{train}'$
# - transform $X_{train}'$
# - transform $X_{test}'$
#
# Compare this transformed $X_{test}'$ with $X_{test}''$ where $X_{test}''$ comes from fitting the polynomial features to $X_{test}'$ and transforming $X_{test}'$. You can check directly by using ```==``` and then sum it up. If the value is same as the length, then you know that they are the same, as a boolean True evaluates to 1.

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_feature = PolynomialFeatures(degree= 2)
poly_X_train = poly_feature.fit_transform(scale_X_train)
poly_X_test = poly_feature.transform(scale_X_test)

# print(poly_X_train.shape, poly_X_test.shape)
print(scale_X_train.shape, poly_X_train.shape)

compare = scale_X_train == poly_X_train[:,:2]
print("Matching element", compare.all())
# Out:
# (170, 2) (170, 6)
# Matching element False

# %% [markdown]
# ---
# ## 4. Polynomial regression  (*)
#
# We will now investigate the training loss and testing loss for different degrees of polynomial. Loop through degrees 1 to 4 (inclusive) and:
# - instantiate an object of PolynomialFeatures with that degree
# - fit and transform $X_{train}'$ and $X_{test}$ to create polynomial features
# - perform linear regression on these polynomial features (polynomial regression)
# - predict on both the training and testing data to record RMSE for training and testing for each iteration of the loop
#
# Now plot the results in the same figure. Do you notice anything special?
#
# <details>
#
# <summary>Answer</summary>
#
# <img src="../assets/E3_overfitting.png" height="300"/>
#
# </details>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error

def poly_regression(scale_X_train, X_test, y_train, y_test):
    train_rmse = []
    test_rmse = []
    deg = (1,2,3,4)
    for i in deg:
        poly_features = PolynomialFeatures(degree=i)
        polyScale_X_train = poly_features.fit_transform(scale_X_train)
        poly_X_test = poly_features.transform(X_test)

        model = LinearRegression()
        model.fit(polyScale_X_train, y_train)

        y_pred_psX_train = model.predict(polyScale_X_train)
        y_pred = model.predict(poly_X_test)
        

        test_RMSE = root_mean_squared_error(y_test, y_pred)
        psX_train_RMSE =root_mean_squared_error(y_train, y_pred_psX_train)

        train_rmse.append(psX_train_RMSE)
        test_rmse.append(test_RMSE)
    
    return train_rmse,test_rmse

poly = poly_regression(scale_X_train, X_test, y_train, y_test)

plt.plot(range(1,5), train_rmse, label="Training")
plt.plot(range(1,5), test_rmse, label="Test")
plt.xlabel("Degrees")
plt.ylabel("Loss")
plt.legend("Training and Test losses of different degrees")
plt.legend()
plt.show()
# Out:
# c:\Users\emil_\git\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but PolynomialFeatures was fitted without feature names
#
# c:\Users\emil_\git\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but PolynomialFeatures was fitted without feature names
#
# c:\Users\emil_\git\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but PolynomialFeatures was fitted without feature names
#
# c:\Users\emil_\git\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but PolynomialFeatures was fitted without feature names

# %% [markdown]
# ---
# ## 5. Regularization methods (*)
#
# Now we will try the regularization methods: ridge regression, lasso regression and elasticnet regression. In the following tasks, use degree = 4.
#
# &nbsp; a) Use ridge regression with cross-validation and test out different alpha-values. I used $\alpha=[0.01, 0.1, 0.5, 1, 5, 10]$ in the cross-validation.
# - Check which alpha, that the cross-validation chose as the best one.
# - Check the weights.
# - Check MAE, MSE, RMSE.
#
# &nbsp; b) Use lasso regression with cross-validation and choose number of alphas to 100. If you get a warning that the algorithm is not converging, increase the max iterations, I chose 10000 iterations.
# - Check which alpha, that the cross-validation chose as the best one.
# - Check the weights.
# - Check MAE, MSE, RMSE.
#
# &nbsp; c) Use elasticnet regression with cross-validation and choose number of alphas to 100. If you get a warning that the algorithm is not converging, increase the max iterations, I chose 10000 iterations. Choose a set of $\ell_1$ ratios for it to try out. I chose $\ell_1 = [.001, .01, .05, .1, .5, .9, .95, 1]$
# - Check which alpha, that the cross-validation chose as the best one.
# - Check the weights.
# - Check MAE, MSE, RMSE.
#
# <details>
#
# <summary>Answer</summary>
#
# a)
#
# Chosen alpha from cross-validation 5.0
#
# Weights: [ 0.          0.91469637  0.23893931 -0.67583593  0.20550801 -0.01369317
#  -0.26007685  0.31867863 -0.03429744 -0.12484035  0.16000319 -0.18105113
#   0.24878399 -0.12692847  0.05002613]
#
# Mean absolute error: 0.831
#
# Mean squared error: 2.208
#
# Root mean squared error: 1.486
#
# b)
#
# Chosen alpha from cross-validation 0.208
#
# Weights: [ 0.          0.23469707  0.         -0.         -0.          0.
#   0.08814685  0.09735986  0.          0.03219702  0.          0.
#   0.         -0.          0.        ]
#
# Mean absolute error: 0.823
#
# Mean squared error: 1.345
#
# Root mean squared error: 1.160
#
# c)
#
# Chosen alpha from cross-validation 0.107
#
# Mean absolute error: 0.761
#
# Root mean squared error: 1.139
#
# L1_ratio: 0.9
#
# Weights: [ 0.          0.23469707  0.         -0.         -0.          0.
#   0.08814685  0.09735986  0.          0.03219702  0.          0.
#   0.         -0.          0.        ]
#
#
# </details>

# %% [markdown]
# ---
#
# Kokchun Giang
#
# [LinkedIn][linkedIn_kokchun]
#
# [GitHub portfolio][github_portfolio]
#
# [linkedIn_kokchun]: https://www.linkedin.com/in/kokchungiang/
# [github_portfolio]: https://github.com/kokchun/Portfolio-Kokchun-Giang
#
# ---
